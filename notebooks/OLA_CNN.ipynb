# %% [markdown]
# <a href="https://colab.research.google.com/github/jal9o3/OLA/blob/dev/OLA_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the data

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np

class CustomDataset(Dataset):
    def __init__(self, csv_file):
        self.data = pd.read_csv(csv_file, header=None)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx].values.astype(np.float32)
        input_data = row[:144].reshape(2, 8, 9)  # Reshaping to (2, 8, 9)
        output_data = row[147:]  # Selecting the 254 output values
        return torch.tensor(input_data), torch.tensor(output_data)

dataset = CustomDataset('training_data.csv')
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %% [markdown]
# # Define the model

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=2, out_channels=16, kernel_size=3)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3)
        self.fc1 = nn.Linear(32 * 4 * 5, 128)  # Adjust dimensions based on your architecture
        self.fc2 = nn.Linear(128, 254)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1)  # Flattening
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# # Train the model

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Assuming CNNModel and dataloader are already defined as per previous discussions

# Initialize the model
model = CNNModel()

# Define the loss function and optimizer
criterion = nn.MSELoss()  # Mean Squared Error for regression tasks
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Number of epochs
num_epochs = 20

# Training loop
for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    running_loss = 0.0

    for inputs, targets in dataloader:
        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)

        # Compute the loss
        loss = criterion(outputs, targets)

        # Backward pass
        loss.backward()

        # Optimize the weights
        optimizer.step()

        # Accumulate the loss
        running_loss += loss.item()

    # Print average loss for the epoch
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(dataloader):.4f}")

print("Training complete.")
# Out:
# Epoch [1/20], Loss: 0.0023
# Epoch [2/20], Loss: 0.0012
# Epoch [3/20], Loss: 0.0012
# Epoch [4/20], Loss: 0.0012
# Epoch [5/20], Loss: 0.0012
# Epoch [6/20], Loss: 0.0012
# Epoch [7/20], Loss: 0.0012
# Epoch [8/20], Loss: 0.0012
# Epoch [9/20], Loss: 0.0012
# Epoch [10/20], Loss: 0.0012
# Epoch [11/20], Loss: 0.0012
# Epoch [12/20], Loss: 0.0012
# Epoch [13/20], Loss: 0.0012
# Epoch [14/20], Loss: 0.0012
# Epoch [15/20], Loss: 0.0012
# Epoch [16/20], Loss: 0.0012
# Epoch [17/20], Loss: 0.0012
# Epoch [18/20], Loss: 0.0012
# Epoch [19/20], Loss: 0.0012
# Epoch [20/20], Loss: 0.0012
# Training complete.

# %% [markdown]
# # Save the model

# %%
torch.save(model.state_dict(), 'model.pth')

# %% [markdown]
# # Clone the OLA engine repository

# %%
# !git clone https://github.com/jal9o3/OLA.git
# Out:
# Cloning into 'OLA'...
# remote: Enumerating objects: 1025, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 1025 (delta 177), reused 170 (delta 91), pack-reused 758 (from 1)
# Receiving objects: 100% (1025/1025), 381.51 KiB | 9.08 MiB/s, done.
# Resolving deltas: 100% (638/638), done.

# %%
# !cd OLA && git checkout dev
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %% [markdown]
# # Define new match simulator to analyze winrate

# %%
import os
os.chdir('./OLA')

# %%
import random

import matplotlib.pyplot as plt

from OLA.core import Board, Infostate, Player
from OLA.constants import Controller
from OLA.training import (TimelessBoard, CFRTrainingSimulator, DirectionFilter,
                      ActionsFilter)
from OLA.simulation import MatchSimulator

class TestingController(Controller):
  """
  This adds the model as a new possible controller.
  """
  MODEL = 3


class ModelTestingSimulator(CFRTrainingSimulator):
  """
  This simulates a match that utilizes a trained OLA model.
  """

  def __init__(self, formations: list[list[int]], controllers: list[int],
                 save_data: bool, pov: int):
        super().__init__(formations, controllers, save_data, pov)
        self.controllers = controllers # Undo the nullification in superclass

  @staticmethod
  def get_model_decision(model, board: Board, infostate: Infostate,
                         actions_filter: ActionsFilter):
    """
    This is for obtaining the model's chosen action.
    """
    input_infostate = list(map(int, str(infostate).split(" ")))

    # Extract the first 144 elements and convert to a NumPy array
    input_data = np.array(input_infostate[:144], dtype=np.float32)

    # Reshape to (8, 9, 2)
    reshaped_data = input_data.reshape(8, 9, 2)

    # Transpose to (2, 8, 9) to match (C, H, W)
    transposed_data = np.transpose(reshaped_data, (2, 0, 1))

    # Convert to a PyTorch tensor and add a batch dimension to make it (1, 2, 8, 9)
    input_tensor = torch.tensor(transposed_data).unsqueeze(0)

    full_strategy = model(input_tensor)
    # Get the probabilities for each action from the model output
    full_strategy = full_strategy.squeeze(0).tolist()

    fullgame_actions = TimelessBoard.actions()
    valid_actions = board.actions()
    strategy = [0.0 for _ in range(len(valid_actions))]
    for action in fullgame_actions:
        if action not in valid_actions:
            full_strategy[fullgame_actions.index(action)] = 0.0
    if sum(full_strategy) > 0:
        full_strategy = [x / sum(full_strategy) for x in full_strategy]

    for i, action in enumerate(fullgame_actions):
        if action in valid_actions:
          strategy[valid_actions.index(action)] = full_strategy[i]
    if sum(strategy) <= 0:
        strategy = [1/len(valid_actions) for _ in range(len(valid_actions))]

    filtered_actions = actions_filter.filter()
    filtered_strategy = []
    for a, action in enumerate(valid_actions):
        if action in filtered_actions:
            filtered_strategy.append(strategy[a])
    normalizing_sum = sum(filtered_strategy)
    if normalizing_sum > 0:
        filtered_strategy = [
            p/normalizing_sum for p in filtered_strategy]
    else:
        # Reset options if all evaluated actions seem bad
        filtered_actions, filtered_strategy = valid_actions, strategy
    action = random.choices(
        filtered_actions, weights=filtered_strategy, k=1)[0]

    return action

  def get_controller_input(self, arbiter_board: Board, infostate: Infostate,
                           actions_filter: ActionsFilter):
      """
      This is for obtaining the controller's chosen action, be it human or
      bot.
      """
      action = "" # Initialize needed value
      valid_actions = arbiter_board.actions()
      if self.get_current_controller(arbiter_board) == Controller.RANDOM:
          action = random.choice(valid_actions)
      elif self.get_current_controller(arbiter_board) == Controller.HUMAN:
          while action not in valid_actions:
              action = input("Choose a move: ")
      elif self.get_current_controller(arbiter_board) == TestingController.MODEL:
          model = CNNModel()
          model.load_state_dict(torch.load('../model.pth'))
          model.eval()
          action = self.get_model_decision(model, arbiter_board, infostate,
                                           actions_filter)

      return action

  def start(self, iterations: int = 1, target: int = None):
    """
    This is the starting method for the match simulation.
    """
    model_wins = 0
    winning_data = [] # Initialize the data to plot
    for iteration in range(iterations):
      if ((self.player_one_color == Player.BLUE and self.controllers[0] != Controller.RANDOM)
          or (self.player_two_color == Player.BLUE and self.controllers[1] != Controller.RANDOM)):
        self.blue_formation = list(
                  Player.get_sensible_random_formation(
                      piece_list=Ranking.SORTED_FORMATION)
              )
      else:
        self.blue_formation = list(Player.get_random_formation(
            piece_list=Ranking.SORTED_FORMATION))

      if ((self.player_one_color == Player.RED and self.controllers[0] != Controller.RANDOM)
          or (self.player_two_color == Player.RED and self.controllers[1] != Controller.RANDOM)):
        self.red_formation = self._place_in_red_range(list(
            Player.get_sensible_random_formation(
                piece_list=Ranking.SORTED_FORMATION))
        )
      else:
        self.red_formation = self._place_in_red_range(list(
            Player.get_random_formation(
                piece_list=Ranking.SORTED_FORMATION))
        )
      arbiter_board = Board(self.setup_arbiter_matrix(),
                                    player_to_move=Player.BLUE,
                                    blue_anticipating=False, red_anticipating=False)
      blue_infostate, red_infostate = MatchSimulator._starting_infostates(
                  arbiter_board)
      action, result, previous_action, previous_result, attack_location = (
                  "", "", "", "", None)  # Initialize needed values
      turn_number = 1
      branches_encountered = 0
      while not arbiter_board.is_terminal():
          self.manage_pov_switching(arbiter_board)

          MatchSimulator._print_game_status(turn_number, arbiter_board,
                                            infostates=[
                                                blue_infostate,
                                                red_infostate],
                                            pov=self.pov)
          valid_actions = arbiter_board.actions()
          branches_encountered += len(valid_actions)

          action = ""  # Initialize variable for storing chosen action
          relevant_infostate = (blue_infostate if arbiter_board.player_to_move == Player.BLUE
                                else red_infostate)

          # For the first turns of each player, choose a forward move
          if turn_number in [1, 2]:
              actions_filter = ActionsFilter(state=arbiter_board, directions=DirectionFilter(
                  back=False, right=False, left=False),
                  square_whitelist=[(x, y) for y in range(Board.COLUMNS)
                                    for x in range(Board.ROWS)])
          else:
              actions_filter = CFRTrainingSimulator._get_actions_filter(
                  arbiter_board, previous_action, previous_result, attack_location)

          action = self.get_controller_input(arbiter_board, relevant_infostate,
                                            actions_filter)
          print(f"Chosen Move: {action}")
          previous_action = action  # Store for the next iteration

          new_arbiter_board = arbiter_board.transition(action)
          arbiter_board, result, attack_location = self._process_action(
                      arbiter_board, action)
          previous_result = result  # Store for the next iteration
          blue_infostate, red_infostate = MatchSimulator._update_infostates(
              blue_infostate, red_infostate, action=action, result=result
          )
          arbiter_board = new_arbiter_board
          turn_number += 1

          print(f"Model Wins: {model_wins}")
          print(f"Iteration: {iteration + 1}/{iterations}")

      MatchSimulator._print_result(arbiter_board)
      match_result = MatchSimulator._get_match_result(arbiter_board)
      if match_result == self.player_two_color: # Model controller is Player 2
        model_wins += 1
      model_color = "BLUE" if self.player_two_color == Player.BLUE else "RED"
      print(f"Model: {model_color}")

      winning_data.append([model_wins, iteration + 1])

    print(f"Model Winrate: {(model_wins/iterations)*100: .2f}")

    # Calculate the percentage ratios
    percentages = [(a / b) * 100 for a, b in winning_data]

    # Plotting
    plt.figure(figsize=(10, 5))
    plt.plot(percentages, marker='o', linestyle='-', color='b')
    plt.title('Win Rate over Measurement Iterations')
    plt.xlabel('Iteration #')
    plt.ylabel('Measured Win Rate (%)')
    plt.grid(True)
    plt.show()

# %%
from OLA.constants import Ranking, Controller, POV

# Sample random formations
blue_formation = list(
    Player.get_sensible_random_formation(
        piece_list=Ranking.SORTED_FORMATION)
)
red_formation = list(
    Player.get_sensible_random_formation(
        piece_list=Ranking.SORTED_FORMATION)
)

match_simulator = ModelTestingSimulator(formations=[blue_formation, red_formation],
                                  controllers=[
                                      Controller.RANDOM, TestingController.MODEL],
                                  save_data=False,
                                  pov=POV.WORLD)
match_simulator.start(iterations=500)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  - bA  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  -  - r2  -  -  -  -
#  5   - r2 b9 b8  -  -  - r4 r2
#  6  r9  -  - rA r2  - r1 rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 5343
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 94
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  - bA  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b8 r2  -  -  -  -
#  5   - r2 b9  -  -  -  - r4 r2
#  6  r9  -  - rA r2  - r1 rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6665
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 95
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  - bA  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b8 r2  -  -  -  -
#  5   - r2 b9  -  -  -  - r4 r2
#  6  r9  -  - rA r2 r1  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4344
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 96
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  - bA  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  -  - b8  -  -  -  -
#  5   - r2 b9  -  -  -  - r4 r2
#  6  r9  -  - rA r2 r1  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6454
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 97
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  - bA  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  -  - b8  -  -  -  -
#  5   - r2 b9  - r2  -  - r4 r2
#  6  r9  -  - rA  - r1  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4434
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 98
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  - bA  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   -  -  -  -  -  -  -  -  -
#  5   - r2 b9  - r2  -  - r4 r2
#  6  r9  -  - rA  - r1  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5141
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 99
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  - bA  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   - r2  -  -  -  -  -  -  -
#  5   -  - b9  - r2  -  - r4 r2
#  6  r9  -  - rA  - r1  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2333
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 100
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  - bA b8  -  -  -  -
#  4   - r2  -  -  -  -  -  -  -
#  5   -  - b9  - r2  -  - r4 r2
#  6  r9  -  - rA  - r1  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6555
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 101
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  - bA b8  -  -  -  -
#  4   - r2  -  -  -  -  -  -  -
#  5   -  - b9  - r2 r1  - r4 r2
#  6  r9  -  - rA  -  -  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3343
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 102
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   - r2  - bA  -  -  -  -  -
#  5   -  - b9  - r2 r1  - r4 r2
#  6  r9  -  - rA  -  -  - rF  -
#  7  rE rF rD  - rB  -  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6777
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 103
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   - r2  - bA  -  -  -  -  -
#  5   -  - b9  - r2 r1  - r4 r2
#  6  r9  -  - rA  -  -  -  -  -
#  7  rE rF rD  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3444
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 104
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   - r2  - bA b8  -  -  -  -
#  5   -  - b9  - r2 r1  - r4 r2
#  6  r9  -  - rA  -  -  -  -  -
#  7  rE rF rD  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7262
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 105
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   - r2  - bA b8  -  -  -  -
#  5   -  - b9  - r2 r1  - r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE rF  -  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 5242
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 106
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   - r2 b9 bA b8  -  -  -  -
#  5   -  -  -  - r2 r1  - r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE rF  -  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5556
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 107
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   - r2 b9 bA b8  -  -  -  -
#  5   -  -  -  - r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE rF  -  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4434
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 108
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   - r2 b9 bA  -  -  -  -  -
#  5   -  -  -  - r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE rF  -  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7172
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 109
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   - r2 b9 bA  -  -  -  -  -
#  5   -  -  -  - r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE  - rF  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4353
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 110
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   - r2 b9  -  -  -  -  -  -
#  5   -  -  - bA r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE  - rF  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 4142
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 111
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  - b8  -  -  -  -
#  4   -  - b9  -  -  -  -  -  -
#  5   -  -  - bA r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE  - rF  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3141
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 112
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  - b8  -  -  -  -
#  4   - bD b9  -  -  -  -  -  -
#  5   -  -  - bA r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE  - rF  - rB  -  - rF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7776
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 113
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  - b8  -  -  -  -
#  4   - bD b9  -  -  -  -  -  -
#  5   -  -  - bA r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE  - rF  - rB  - rF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3444
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 114
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD b9  - b8  -  -  -  -
#  5   -  -  - bA r2  - r1 r4 r2
#  6  r9  - rD rA  -  -  -  -  -
#  7  rE  - rF  - rB  - rF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6252
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 115
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD b9  - b8  -  -  -  -
#  5   -  - rD bA r2  - r1 r4 r2
#  6  r9  -  - rA  -  -  -  -  -
#  7  rE  - rF  - rB  - rF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4243
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 116
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD  - b9 b8  -  -  -  -
#  5   -  - rD bA r2  - r1 r4 r2
#  6  r9  -  - rA  -  -  -  -  -
#  7  rE  - rF  - rB  - rF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7675
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 117
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD  - b9 b8  -  -  -  -
#  5   -  - rD bA r2  - r1 r4 r2
#  6  r9  -  - rA  -  -  -  -  -
#  7  rE  - rF  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4454
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 118
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD  - b9  -  -  -  -  -
#  5   -  - rD bA b8  - r1 r4 r2
#  6  r9  -  - rA  -  -  -  -  -
#  7  rE  - rF  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6061
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 119
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD  - b9  -  -  -  -  -
#  5   -  - rD bA b8  - r1 r4 r2
#  6   - r9  - rA  -  -  -  -  -
#  7  rE  - rF  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4151
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 120
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   -  -  - b9  -  -  -  -  -
#  5   - bD rD bA b8  - r1 r4 r2
#  6   - r9  - rA  -  -  -  -  -
#  7  rE  - rF  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7273
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 121
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   -  -  - b9  -  -  -  -  -
#  5   - bD rD bA b8  - r1 r4 r2
#  6   - r9  - rA  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 5141
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 122
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD  - b9  -  -  -  -  -
#  5   -  - rD bA b8  - r1 r4 r2
#  6   - r9  - rA  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6353
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 123
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   -  -  -  -  -  -  -  -  -
#  4   - bD  - b9  -  -  -  -  -
#  5   -  - rD  - b8  - r1 r4 r2
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4131
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 124
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9  -  -  -  -  -
#  5   -  - rD  - b8  - r1 r4 r2
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5767
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 125
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  - b7
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9  -  -  -  -  -
#  5   -  - rD  - b8  - r1  - r2
#  6   - r9  -  -  -  -  - r4  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2838
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 126
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  - b7
#  4   -  -  - b9  -  -  -  -  -
#  5   -  - rD  - b8  - r1  - r2
#  6   - r9  -  -  -  -  - r4  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5848
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 127
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  - b7
#  4   -  -  - b9  -  -  -  - r2
#  5   -  - rD  - b8  - r1  -  -
#  6   - r9  -  -  -  -  - r4  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3848
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 128
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9  -  -  -  - b7
#  5   -  - rD  - b8  - r1  -  -
#  6   - r9  -  -  -  -  - r4  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5251
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 129
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9  -  -  -  - b7
#  5   - rD  -  - b8  - r1  -  -
#  6   - r9  -  -  -  -  - r4  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 5444
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 130
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9 b8  -  -  - b7
#  5   - rD  -  -  -  - r1  -  -
#  6   - r9  -  -  -  -  - r4  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6757
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 131
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9 b8  -  -  - b7
#  5   - rD  -  -  -  - r1 r4  -
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4847
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 132
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9 b8  -  - b7  -
#  5   - rD  -  -  -  - r1 r4  -
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5655
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 133
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9 b8  -  - b7  -
#  5   - rD  -  -  - r1  - r4  -
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4748
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 134
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9 b8  -  -  - b7
#  5   - rD  -  -  - r1  - r4  -
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5150
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 135
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  - b9 b8  -  -  - b7
#  5  rD  -  -  -  - r1  - r4  -
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4342
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 136
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  - b9  - b8  -  -  - b7
#  5  rD  -  -  -  - r1  - r4  -
#  6   - r9  -  -  -  -  -  -  -
#  7  rE  -  - rF rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7363
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 137
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  - b9  - b8  -  -  - b7
#  5  rD  -  -  -  - r1  - r4  -
#  6   - r9  - rF  -  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4252
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 138
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  -  - b8  -  -  - b7
#  5  rD  - b9  -  - r1  - r4  -
#  6   - r9  - rF  -  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6362
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 139
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  -  -  -  -  -  -
#  4   -  -  -  - b8  -  -  - b7
#  5  rD  - b9  -  - r1  - r4  -
#  6   - r9 rF  -  -  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4434
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 140
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  -  -  -
#  4   -  -  -  -  -  -  -  - b7
#  5  rD  - b9  -  - r1  - r4  -
#  6   - r9 rF  -  -  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5565
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 141
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  -  -  -
#  4   -  -  -  -  -  -  -  - b7
#  5  rD  - b9  -  -  -  - r4  -
#  6   - r9 rF  -  - r1  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4847
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 142
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  -  -  -
#  4   -  -  -  -  -  -  - b7  -
#  5  rD  - b9  -  -  -  - r4  -
#  6   - r9 rF  -  - r1  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6564
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 143
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  -  -  -
#  4   -  -  -  -  -  -  - b7  -
#  5  rD  - b9  -  -  -  - r4  -
#  6   - r9 rF  - r1  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4737
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 144
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  - b7  -
#  4   -  -  -  -  -  -  -  -  -
#  5  rD  - b9  -  -  -  - r4  -
#  6   - r9 rF  - r1  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5758
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 145
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  - b7  -
#  4   -  -  -  -  -  -  -  -  -
#  5  rD  - b9  -  -  -  -  - r4
#  6   - r9 rF  - r1  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3738
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 146
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  -  - b7
#  4   -  -  -  -  -  -  -  -  -
#  5  rD  - b9  -  -  -  -  - r4
#  6   - r9 rF  - r1  -  -  -  -
#  7  rE  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7060
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 147
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   - bE b2  - b2 b3 bF b2 bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bD  -  - b8  -  -  - b7
#  4   -  -  -  -  -  -  -  -  -
#  5  rD  - b9  -  -  -  -  - r4
#  6  rE r9 rF  - r1  -  -  -  -
#  7   -  -  -  - rB rF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  - b3  -  -  -  - bF
#  2   - bE  -  -  -  -  -  -  -
#  3   -  -  -  -  -  -  -  -  -
#  4   - b2  - rE  -  -  -  - rF
#  5   -  -  -  -  -  -  -  -  -
#  6   -  -  -  -  -  -  -  -  -
#  7  r9  -  - rD r1  - r4 bF  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 7776
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 370
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  - b3  -  -  -  - bF
#  2   - bE  -  -  -  -  -  -  -
#  3   -  -  -  -  -  -  -  -  -
#  4   - b2  - rE  -  -  -  - rF
#  5   -  -  -  -  -  -  -  -  -
#  6   -  -  -  -  -  -  -  -  -
#  7  r9  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7060
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 371
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  - b3  -  -  -  - bF
#  2   - bE  -  -  -  -  -  -  -
#  3   -  -  -  -  -  -  -  -  -
#  4   - b2  - rE  -  -  -  - rF
#  5   -  -  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4151
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 372
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  - b3  -  -  -  - bF
#  2   - bE  -  -  -  -  -  -  -
#  3   -  -  -  -  -  -  -  -  -
#  4   -  -  - rE  -  -  -  - rF
#  5   - b2  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 4342
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 373
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  - b3  -  -  -  - bF
#  2   - bE  -  -  -  -  -  -  -
#  3   -  -  -  -  -  -  -  -  -
#  4   -  - rE  -  -  -  -  - rF
#  5   - b2  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2131
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 374
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  - b3  -  -  -  - bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bE  -  -  -  -  -  -  -
#  4   -  - rE  -  -  -  -  - rF
#  5   - b2  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 4252
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 375
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  - b3  -  -  -  - bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bE  -  -  -  -  -  -  -
#  4   -  -  -  -  -  -  -  - rF
#  5   - b2 rE  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 1323
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 376
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  - bF
#  2   -  -  - b3  -  -  -  -  -
#  3   - bE  -  -  -  -  -  -  -
#  4   -  -  -  -  -  -  -  - rF
#  5   - b2 rE  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5251
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 377
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  - bF
#  2   -  -  - b3  -  -  -  -  -
#  3   - bE  -  -  -  -  -  -  -
#  4   -  -  -  -  -  -  -  - rF
#  5   - rE  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2333
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 378
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  - bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bE  - b3  -  -  -  -  -
#  4   -  -  -  -  -  -  -  - rF
#  5   - rE  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 4838
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 379
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  - bF
#  2   -  -  -  -  -  -  -  -  -
#  3   - bE  - b3  -  -  -  - rF
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 1828
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 380
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  -  - bF
#  3   - bE  - b3  -  -  -  - rF
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7372
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 381
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  -  - bF
#  3   - bE  - b3  -  -  -  - rF
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  - rD  - r1  - bF  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 7675
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 382
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  -  - bF
#  3   - bE  - b3  -  -  -  - rF
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  - rD  - r1 bF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5141
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 383
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  -  - bF
#  3   - bE  - b3  -  -  -  - rF
#  4   - rE  -  -  -  -  -  -  -
#  5   -  -  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  - rD  - r1 bF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3334
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 384
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  -  - bF
#  3   - bE  -  - b3  -  -  - rF
#  4   - rE  -  -  -  -  -  -  -
#  5   -  -  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  - rD  - r1 bF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 3848
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 385
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  -  - bF
#  3   - bE  -  - b3  -  -  -  -
#  4   - rE  -  -  -  -  -  - rF
#  5   -  -  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  - rD  - r1 bF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2827
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 386
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  - bF  -
#  3   - bE  -  - b3  -  -  -  -
#  4   - rE  -  -  -  -  -  - rF
#  5   -  -  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  - rD  - r1 bF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7273
# Model Wins: 434
# Iteration: 499/500
# Turn Number: 387
#
#  0  b6 bB b4  - b2  - b5 b1 b2
#  1   -  -  -  -  -  -  -  -  -
#  2   -  -  -  -  -  -  - bF  -
#  3   - bE  -  - b3  -  -  -  -
#  4   - rE  -  -  -  -  -  - rF
#  5   -  -  -  -  -  -  -  -  -
#  6  r9  -  -  -  -  -  -  -  -
#  7   -  -  - rD r1 bF  -  -  -
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 7574
# Model Wins: 434
# Iteration: 499/500
#
# [VICTORY FOR BLUE]
#
# Model: BLUE
# Turn Number: 1
#
#  0  b1 bF b6 b7 b2 b3 b2 b2 b4
#  1   - bF bB  - b2 bA bE b2  -
#  2  b2 b9 bD b5  - bC  -  - b8
#  3   -  -  -  -  -  -  -  -  -
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE r2 r1 r5 r2 rF r7 rF
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2232
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 2
#
#  0  b1 bF b6 b7 b2 b3 b2 b2 b4
#  1   - bF bB  - b2 bA bE b2  -
#  2  b2 b9  - b5  - bC  -  - b8
#  3   -  - bD  -  -  -  -  -  -
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE r2 r1 r5 r2 rF r7 rF
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5848
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 3
#
#  0  b1 bF b6 b7 b2 b3 b2 b2 b4
#  1   - bF bB  - b2 bA bE b2  -
#  2  b2 b9  - b5  - bC  -  - b8
#  3   -  - bD  -  -  -  -  -  -
#  4   -  -  -  -  -  -  -  - rF
#  5   - rE r2 r1 r5 r2 rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2838
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 4
#
#  0  b1 bF b6 b7 b2 b3 b2 b2 b4
#  1   - bF bB  - b2 bA bE b2  -
#  2  b2 b9  - b5  - bC  -  -  -
#  3   -  - bD  -  -  -  -  - b8
#  4   -  -  -  -  -  -  -  - rF
#  5   - rE r2 r1 r5 r2 rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 4838
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 5
#
#  0  b1 bF b6 b7 b2 b3 b2 b2 b4
#  1   - bF bB  - b2 bA bE b2  -
#  2  b2 b9  - b5  - bC  -  -  -
#  3   -  - bD  -  -  -  -  - rF
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE r2 r1 r5 r2 rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 0818
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 6
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2  b2 b9  - b5  - bC  -  -  -
#  3   -  - bD  -  -  -  -  - rF
#  4   -  -  -  -  -  -  -  -  -
#  5   - rE r2 r1 r5 r2 rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5545
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 7
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2  b2 b9  - b5  - bC  -  -  -
#  3   -  - bD  -  -  -  -  - rF
#  4   -  -  -  -  - r2  -  -  -
#  5   - rE r2 r1 r5  - rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2333
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 8
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2  b2 b9  -  -  - bC  -  -  -
#  3   -  - bD b5  -  -  -  - rF
#  4   -  -  -  -  - r2  -  -  -
#  5   - rE r2 r1 r5  - rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5150
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 9
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2  b2 b9  -  -  - bC  -  -  -
#  3   -  - bD b5  -  -  -  - rF
#  4   -  -  -  -  - r2  -  -  -
#  5  rE  - r2 r1 r5  - rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2030
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 10
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   - b9  -  -  - bC  -  -  -
#  3  b2  - bD b5  -  -  -  - rF
#  4   -  -  -  -  - r2  -  -  -
#  5  rE  - r2 r1 r5  - rF r7  -
#  6  rD r2 r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 6151
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 11
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   - b9  -  -  - bC  -  -  -
#  3  b2  - bD b5  -  -  -  - rF
#  4   -  -  -  -  - r2  -  -  -
#  5  rE r2 r2 r1 r5  - rF r7  -
#  6  rD  - r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3040
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 12
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   - b9  -  -  - bC  -  -  -
#  3   -  - bD b5  -  -  -  - rF
#  4  b2  -  -  -  - r2  -  -  -
#  5  rE r2 r2 r1 r5  - rF r7  -
#  6  rD  - r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 5242
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 13
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   - b9  -  -  - bC  -  -  -
#  3   -  - bD b5  -  -  -  - rF
#  4  b2  - r2  -  - r2  -  -  -
#  5  rE r2  - r1 r5  - rF r7  -
#  6  rD  - r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 2131
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 14
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   -  -  -  -  - bC  -  -  -
#  3   - b9 bD b5  -  -  -  - rF
#  4  b2  - r2  -  - r2  -  -  -
#  5  rE r2  - r1 r5  - rF r7  -
#  6  rD  - r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3  - r4  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7675
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 15
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   -  -  -  -  - bC  -  -  -
#  3   - b9 bD b5  -  -  -  - rF
#  4  b2  - r2  -  - r2  -  -  -
#  5  rE r2  - r1 r5  - rF r7  -
#  6  rD  - r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3 r4  -  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 3343
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 16
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   -  -  -  -  - bC  -  -  -
#  3   - b9 bD  -  -  -  -  - rF
#  4  b2  - r2 b5  - r2  -  -  -
#  5  rE r2  - r1 r5  - rF r7  -
#  6  rD  - r2 rC  - r9 r2 rA rB
#  7   - r6 r2  - r3 r4  -  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 2
# Chosen Move: 7161
# Model Wins: 435
# Iteration: 500/500
# Turn Number: 17
#
#  0  b1 bF b6 b7 b2 b3 b2 b2  -
#  1   - bF bB  - b2 bA bE b2 b4
#  2   -  -  -  -  - bC  -  -  -
#  3   - b9 bD  -  -  -  -  - rF
#  4  b2  - r2 b5  - r2  -  -  -
#  5  rE r2  - r1 r5  - rF r7  -
#  6  rD r6 r2 rC  - r9 r2 rA rB
#  7   -  - r2  - r3 r4  -  - r8
#
#      0  1  2  3  4  5  6  7  8
# Player to move: 1
# Chosen Move: 4353
# Model Wins: 435
# Iteration: 500/500
#
# [VICTORY FOR BLUE]
#
# Model: BLUE
# Model Winrate:  87.20
